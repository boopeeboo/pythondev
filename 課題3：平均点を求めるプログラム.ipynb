# %%
i = 0
j = 0
s = 0
a = 0

while True:
    
    i = int(input("点数を入力してください："))
    if i == -1:
        break
    s += i
    print ("点数を入力してください："+ str(i))
  
    j += 1

a = round(s / j, 1) 

print(str(j) + "人のテストの平均点は" + str(a) + "点です。")
# Out:
# 点数を入力してください：11
# 点数を入力してください：11
# 点数を入力してください：10
# 点数を入力してください：10
# 4人のテストの平均点は10.5点です。

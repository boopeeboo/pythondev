# %%
name = input("名前を入力してください：")
age = input("現在の年齢を入力してください：")
age = int(age) #入力した文字列を整数に変換
age = age + 1
print("私の名前は " + name + "です。来年で " + str(age) + " 歳になります。") #年齢は文字列に変換
# Out:
# 私の名前は たぬきです。来年で 2 歳になります。

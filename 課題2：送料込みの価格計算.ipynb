# %%
price = int(input("税抜価格を入力してください："))
type = price
price = round(price*1.1)
if price >= 2000:
    print( " 送料は無料です " )
    print(f"送料込みの価格は{price}円です。")
else:
    print("送料として350円かかります")
    Price = int(price)+350
    print("送料込みの価格は" + str(Price) + "です。" )
# Out:
# 送料として350円かかります
# 送料込みの価格は1450です。

# %%
c = []
c = dict.fromkeys(list("abcdefghijkrmnopqrstuvwxyz"), 0)

word = []


while True:
    t1 = input("英単語を入力してください： ")

    if t1 == "":
        break
    word.append(t1)
    print(f"入力した英単語: {t1}")

word.sort()
print(f"入力した英単語： {word}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 13
#      11         break
#      12     word.append(t1)
# ---> 13     print(f"入力した英単語: {t1}")
#      15 word.sort()
#      16 print(f"入力した英単語： {word}")
#
# TypeError: 'str' object is not callable

# %%
while True:
    t1 = input("英単語を入力してください： ")

    if t1 == "":
        break
    word.append(t1)

word.sort()
print(f"入力した英単語： {word}")
